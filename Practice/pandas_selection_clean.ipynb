# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import random

first_names = list(dict.fromkeys([
    "Seema","Sansa","Saisa","Kabita","Nabin","Rajesh","Ramesh","Ashish","Manish","Dipesh",
    "Bikash","Sandesh","Sujan","Kiran","Nabin","Rajesh","Ramesh","Ashish","Manish","Dipesh",
    "pratik","Rohan","Anish","Suman","Bibek","Prabin","Nischal","Sagar","Roshan","Aayush",
    "Bikash","Sandesh","Sujan","Kiran","Nabin","Rajesh","Ramesh","Ashish","Manish","Dipesh",
    "Rahul","Suraj","Samir","Sandeep","Prakash","Pawan","Niraj","Rajan","Arjun","Amit",
    "Anil","Sunil","Santosh","Binod","Bimal","Dinesh","Deepak","Rupesh","Suresh","Siddharth",
    "Sophia","Emma","Olivia","Ava","Mia","Isabella","mahabati","Charlotte","Amelia","Harper",
    "Evelyn","Ella","Grace","govin","Lily","Arya","Zoe","Hina","Maya","Sofia",
    "Liam","Noah","Oliver","James","William","Henry","Lucas","Benjamin","Theodore","Jack",
    "Daniel","Michael","Alex","Mathun","john","David","Samuel","John","grishma","Leo"
]))

# %%
last_names = [
    "chaudhary","Majhi","thandar","Gurung","Shrestha","Rai","Tamang","KC","Adhikari","Poudel",
    "Bhandari","Gautam","Basnet","Bhattarai","Maharjan","Lama","Magar","Rana","Joshi","Dahal",
    "Khanal","Acharya","gacchadar","Pandey","Bista","Bohara","Chaudhary","Yadav","Mishra","Singh",
    "Johnson","tabdar","Williams","Brown","Jones","Miller","Davis","Wilson","Taylor","sharma",
    "sardar","majhi","uraw","Jackson","White","Harris","Clark","Lewis","Young","Walker"
]

# %%
job_titles = [
    "Data Analyst","Software Engineer","Business Analyst","Data Scientist",
    "HR Manager","Marketing Analyst","Financial Analyst","Project Manager",
    "Web Developer","QA Engineer"
]

# %%
import pandas as pd

random.seed(42)
all_names = list({f"{first} {last}" for first in first_names for last in last_names})
random.shuffle(all_names)
names = all_names[:1050]

df = pd.DataFrame({
    "id": range(1, 1051),
    "name": names,
    "salary": [random.randint(30000, 150000) for _ in range(1050)],
    "job_title": [random.choice(job_titles) for _ in range(1050)]
})

df.to_csv("company_data_1050.csv", index=False)

# %%
print("total data:", len(df))
print("duplicate checking:", df["name"].duplicated().sum())
df
# Out:
# total data: 1050
# duplicate checking: 0
#         id           name  salary          job_title
# 0        1     Jack Lewis   39506    Project Manager
# 1        2   Sofia Khanal   78967        QA Engineer
# 2        3       Leo uraw  122345    Project Manager
# 3        4   Rajesh Majhi  116787  Software Engineer
# 4        5   Sujan Harris   81851    Project Manager
# ...    ...            ...     ...                ...
# 1045  1046     Grace uraw   82858  Software Engineer
# 1046  1047  Grace Johnson  137099    Project Manager
# 1047  1048    Liam Pandey   60801         HR Manager
# 1048  1049    Kiran Clark   40332  Marketing Analyst
# 1049  1050    Binod majhi   90174  Financial Analyst
#
# [1050 rows x 4 columns]

# %%
df.head(4)
# Out:
#    id          name  salary          job_title
# 0   1    Jack Lewis   39506    Project Manager
# 1   2  Sofia Khanal   78967        QA Engineer
# 2   3      Leo uraw  122345    Project Manager
# 3   4  Rajesh Majhi  116787  Software Engineer

# %%
df.describe()
# Out:
#                 id         salary
# count  1050.000000    1050.000000
# mean    525.500000   90909.953333
# std     303.253195   35116.389639
# min       1.000000   30167.000000
# 25%     263.250000   59834.500000
# 50%     525.500000   91340.500000
# 75%     787.750000  120889.500000
# max    1050.000000  149822.000000
